# %%
"""

Based on the data that you gathered last week, perform the following tasks: 

Plot the distribution of happiness score per country.
Find 10 least happy countries.
What is the average of happiness?
What are the countries above the median
Plot the correlation between 2 pairs of variables 

"""

# %%
""" 

Initial Processing of data:

import pandas as pd
df = pd.read_csv("./result.csv")
df.head(5)
df["Perceptions of corruption"] = df["Perceptions of corruption"].str.replace(r"\\", "", regex=True).str.strip()
df.head(5)
df.to_csv("result.csv", index=False)

"""

# %%
import pandas as pd

# %%
df = pd.read_csv("./result.csv")
df.info()
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  104 non-null    int64
#  1   country                       104 non-null    object
#  2   Score                         104 non-null    float64
#  3   GDP per capita                104 non-null    float64
#  4   Social support                104 non-null    float64
#  5   Healthy life expectancy       104 non-null    float64
#  6   Freedom to make life choices  104 non-null    float64
#  7   Generosity                    104 non-null    float64
#  8   Perceptions of corruption     104 non-null    float64
#  9   continent                     104 non-null    object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 8.2+ KB
#    Overall rank      country  Score  GDP per capita  Social support  \
# ...

# %%
""" 
Based on the data that you gathered last week, perform the following tasks: 

Plot the distribution of happiness score per country. -> Bar graph
Find 10 least happy countries.
What is the average of happiness?
What are the countries above the median
Plot the correlation between 2 pairs of variables 
"""
# Out:
# ' \nBased on the data that you gathered last week, perform the following tasks: \n\nPlot the distribution of happiness score per country. -> Bar graph\nFind 10 least happy countries.\nWhat is the average of happiness?\nWhat are the countries above the median\nPlot the correlation between 2 pairs of variables \n'

# %%
import matplotlib.pyplot as plt

# Sort countries by Happiness Score for better visualization
df_sorted = df.sort_values(by="Score", ascending=False)

# Plot bar chart
plt.figure(figsize=(20, 8))
plt.bar(df_sorted["country"], df_sorted["Score"], color="skyblue")
plt.xlabel("Country")
plt.ylabel("Happiness Score")
plt.title("Happiness Scores by Country")
plt.xticks(rotation=90)  # Rotate country names for readability
plt.show()

# %%
# Find 10 least happy countries.
# already available sorted_df
df_sorted.tail(20)
# Out:
#      Overall rank      country  Score  GDP per capita  Social support  \
# 84             97     Bulgaria  5.011           1.092           1.513
# 85            100        Nepal  4.913           0.446           1.226
# 86            101       Jordan  4.906           0.837           1.225
# 87            105         Laos  4.796           0.764           1.030
# 88            107      Albania  4.719           0.947           0.848
# 89            108    Venezuela  4.707           0.960           1.427
# 90            109     Cambodia  4.700           0.574           1.122
# 91            116      Armenia  4.559           0.850           1.055
# 92            117         Iran  4.548           1.100           0.842
# 93            119      Georgia  4.519           0.886           0.666
# 94            125   Bangladesh  4.456           0.562           0.928
# 95            126         Iraq  4.437           1.043           0.980
# ...

# %%
# What is the average of happiness?
average_happiness = df["Score"].mean()
print(average_happiness)
# Out:
# 5.8067115384615375

# %%
df.rename(columns={"Score": "Happiness score"}, inplace=True)

# %%
df.head(5)
# Out:
#    Overall rank      country  Happiness score  GDP per capita  Social support  \
# 0             1      Finland            7.769           1.340           1.587
# 1             2      Denmark            7.600           1.383           1.573
# 2             3       Norway            7.554           1.488           1.582
# 3             4      Iceland            7.494           1.380           1.624
# 4             5  Netherlands            7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption continent
# 0                      0.393    Europe
# ...

# %%
# What are the countries above the median
# calculate median, filter rows with score > median
median_happiness = df["Happiness score"].median()
print(median_happiness)
# Out:
# 5.888

# %%
countries_above_median_happiness = df[df["Happiness score"]>median_happiness]

# %%
countries_above_median_happiness[["country", "Happiness score"]].head(10)
# Out:
#        country  Happiness score
# 0      Finland            7.769
# 1      Denmark            7.600
# 2       Norway            7.554
# 3      Iceland            7.494
# 4  Netherlands            7.488
# 5  Switzerland            7.480
# 6       Sweden            7.343
# 7  New Zealand            7.307
# 8       Canada            7.278
# 9    Australia            7.228

# %%
# Plot the correlation between 2 pairs of variables 

country_df.info()

# lets plot between rank and gdp
# lets plot bw life expectancy and rank
# lets plot bw
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  104 non-null    int64
#  1   country                       104 non-null    object
#  2   Score                         104 non-null    float64
#  3   GDP per capita                104 non-null    float64
#  4   Social support                104 non-null    float64
#  5   Healthy life expectancy       104 non-null    float64
#  6   Freedom to make life choices  104 non-null    float64
#  7   Generosity                    104 non-null    float64
#  8   Perceptions of corruption     104 non-null    float64
#  9   continent                     104 non-null    object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 8.2+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example: Plotting correlation between "Happiness score" and "GDP"
sns.scatterplot(data=df, x="Happiness score", y="GDP per capita")

# Add labels and title
plt.xlabel("Happiness Score")
plt.ylabel("GDP per Capita")
plt.title("Correlation between Happiness Score and GDP per Capita")

# Show plot
plt.show()

# %%
# Select relevant columns for correlation matrix
corr_df = df[['Overall rank', 'Happiness score', 'GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption',]]

# Calculate correlation matrix
corr_matrix = corr_df.corr()

# Plot heatmap of correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)

plt.title("Correlation Matrix of Variables")
plt.show()

# %%
corr_matrix
# Out:
#                               Overall rank  Happiness score  GDP per capita  \
# Overall rank                      1.000000        -0.987234       -0.726059
# Happiness score                  -0.987234         1.000000        0.736551
# GDP per capita                   -0.726059         0.736551        1.000000
# Social support                   -0.731451         0.742521        0.599618
# Healthy life expectancy          -0.758666         0.774949        0.795017
# Freedom to make life choices     -0.542131         0.583239        0.316183
# Generosity                       -0.043673         0.089487       -0.043607
# Perceptions of corruption        -0.463837         0.526170        0.440600
#
#                               Social support  Healthy life expectancy  \
# Overall rank                       -0.731451                -0.758666
# Happiness score                     0.742521                 0.774949
# GDP per capita                      0.599618                 0.795017
# ...
